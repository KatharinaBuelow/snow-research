# %% [markdown]
# ## Boxplot and stripplot for different hight levels and regions
# Script for each region and time slice:
# comparing hight levels and scenarios
#
# Variable: snow covered area [%]
#
# Inputdat can be found in   ../data/

# %%
import os
import pandas as pd
import numpy as np
import glob
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from cmcrameri import cm
from matplotlib import markers

# %%
### colors : https://www.fabiocrameri.ch/colourmaps/ 
my_cols = {'rcp85': cm.roma(0.00),
               'rcp45': cm.lajolla(0.7), #cm.roma(0.30),
               'rcp26': cm.roma(1.00),
               'rcp85-1971-2000': cm.grayC(0.8)}

# %%
def boxplot_all_exp_region(sel1r, plotdir, title,region, t, var):
 
    print(title)
    OutFile=os.path.join(plotdir,'Boxplot_'+var+'_'+region+'_'+t+'.png')

    fig = plt.figure(figsize=(10,10))
    
    yorder=['3000', '2500','2000','1500','1000','500' ]
    hueorder=['rcp85','rcp45','rcp26','rcp85-1971-2000' ]
  
    sel1r.to_csv('test') 
    ax=sns.stripplot(x=var, y='height', data=sel1r, dodge=True, alpha=0.9, jitter=0.2, 
                  size=3, order=yorder, palette=my_cols, linewidth=1, edgecolor='gray', hue_order= hueorder,hue='experiment')
    
    ax=sns.boxplot(x=var, y='height', data=sel1r, whis=np.inf ,order=yorder, hue_order= hueorder,hue='experiment', 
                   palette=my_cols) #, boxprops=dict(alpha=0.8))
    
    #lable size/fontsize for the Paper 24 
    lz=18
    
    # loc needs to be 4 for variable [snw]
    if region in ['SC','EA']:
        loc_region=2
    else:
        loc_region=4
    if var in ['snw',]:
        loc_region=4
    
    plt.tick_params(bottom=False)
    plt.grid(True)
    #plt.xlim(0,100)
    plt.tick_params(axis='y', labelsize=lz)
    plt.tick_params(axis='x', labelsize=lz)
    if var == 'sca':
        plt.xlim(0,100)
        plt.xlabel('snow cover fraction [%]', fontsize=lz)
    if var == 'snw':
        plt.xlim(0,1000)
        plt.xlabel('snow water equivalent [mm/day]', fontsize=lz)
    if var == 'snowday':
        plt.xlim(0,32)
        plt.xlabel('snow days [days/month]', fontsize=lz)
    plt.ylabel('height [m]', fontsize=lz)
    plt.title(title, color='k', fontsize=lz) 

    handles, labels = ax.get_legend_handles_labels()
    
    l = plt.legend(handles[0:4], labels[0:4], loc=loc_region, borderaxespad=0.5,fontsize=16)  #bbox_to_anchor=(1.05, 1)
    print('Plot will be : ',OutFile)
    plt.savefig(OutFile, bbox_inches='tight')    
    
    return

# %% [markdown]
# ## Chose which Variable you like to plot

# %%
# prepare boxplot for snow cover [%]
# var='sca'
# prepare boxplot for snowcoverduration [day]
# Nov-April Numer per month
#var='snowday'
# prepare boxplot with swe [?]
var='snw'

# %%
# prepare boxplot for each region
reg = ['AL', 'EU', 'EA', 'IP', 'SC']
title = ['Alps', 'Europe', 'Eastern Europe', 'Iberian Peninsula', 'Scandinavia']

#------------------------------
# directory an In and outfile:
#------------------------------

print(os.getcwd())
workdir=os.getcwd()

datadir=workdir.replace('plotting-py/BOXPLOT','data')
print(' ')
print('datafile is read from: ', datadir)
infile='snw_tas_pr_snowday-snowcover_NA_timeslice_areamean_all_level_owd.csv'
input=os.path.join(datadir,infile)
print(' ')
print ('Reading data from = ', input)
print(' ')

#!!!!!!!!!!!!!!!!!!!!!!!!
df = pd.read_csv(input)
#!!!!!!!!!!!!!!!!!!!!!!!!

# column names of Dateframe:
   # file,season,exp,RCM,region,height,snw_1972-2001,pr_1972-2001,tas_1972-2001
   # snowday_1972-2001,sca_1972-2001,
   # snw_2022-2051,pr_2022-2051,tas_2022-2051,snowday_2022-2051,sca_2022-2051,
   # snw_2070-2099,pr_2070-2099,tas_2070-2099,snowday_2070-2099,sca_2070-2099,
   # GCM,diff_snw_2022-2051,pro_diff_snw_2022-2051,diff_pr_2022-2051,
   # pro_diff_pr_2022-2051,diff_tas_2022-2051,diff_snowday_2022-2051,
   # pro_diff_snowday_2022-2051,diff_sca_2022-2051,
   # diff_snw_2070-2099,pro_diff_snw_2070-2099,diff_pr_2070-2099,
   # pro_diff_pr_2070-2099,diff_tas_2070-2099,diff_snowday_2070-2099
   # pro_diff_snowday_2070-2099,diff_sca_2070-2099

plotdir=datadir.replace('data','test-plots/BOXPLOTS/single_timeslice_region/')
# better move to work


if not os.path.exists(plotdir):
    os.makedirs(plotdir)
print(' ')
print('Output will be stored in : ', plotdir)

#---------------------------------------------
# prepare dataframe:
#--------------------------------------------

df['height'].replace('0','500', inplace=True)
df['height'].replace('1','1000', inplace=True)
df['height'].replace('2','1500', inplace=True)
df['height'].replace('3','2000', inplace=True)
df['height'].replace('4','2500', inplace=True)
df['height'].replace('5','3000', inplace=True)

df['exp_n']=df['exp']

# 1. Plots for each region/timeslice, comparisons of the hue=experiment 

sel1=df[['height','exp','region',var+'_1972-2001']]
#print('vorher: ',sel1.columns.unique())
sel1.loc[:,'timeslice'] = '1971-2000'

sel1.rename(columns = {var+'_1972-2001':var}, inplace = True)

#a) select historical rcp85
# rename exp-column with rcp85 to rcp85-1971-2000
sela=sel1.loc[(sel1['exp'] == 'rcp85')]

sela['experiment'] = sela['exp'].str.cat(sela['timeslice'],sep="-")
selb=sela.drop(columns=['exp'])

sel2=df[['height','exp','region',var+'_2022-2051']]
sel2['timeslice']='2021-2050'
sel2.rename(columns = {var+'_2022-2051':var}, inplace = True)

sel3=df[['height','exp','region',var+'_2070-2099']]
sel3['timeslice']='2069-2098'
sel3.rename(columns = {var+'_2070-2099':var}, inplace = True)

df_neu = pd.concat([sel1,sel2,sel3],ignore_index=True)

# just to make it look nicer on the plot
df_neu.rename(columns = {'exp':'experiment'}, inplace = True)

time=('2021-2050', '2069-2098')
for t in time:
    selc= df_neu.loc[ (df_neu['timeslice'] == t)]
    sel = pd.concat([selc,selb], ignore_index=True)
    for r in range(len(reg)):
        
        sel1r = sel.loc[ (sel['region'] == reg[r])]
        
        sel1r.reset_index(drop=True)
        plottitle='November-April '+t+' '+title[r]
        boxplot_all_exp_region(sel1r, plotdir, plottitle, reg[r],t, var)
# Out:
# /home/g/g300047/SCRIPTS/github/snow-research/plotting-py/BOXPLOT
#
# datafile is read from:  /home/g/g300047/SCRIPTS/github/snow-research/data
#
# Reading data from =  /home/g/g300047/SCRIPTS/github/snow-research/data/snw_tas_pr_snowday-snowcover_NA_timeslice_areamean_all_level_owd.csv
#
#
# Output will be stored in :  /home/g/g300047/SCRIPTS/github/snow-research/test-plots/BOXPLOTS/single_timeslice_region/
# November-April 2021-2050 Alps
# /tmp/ipykernel_582624/1127777538.py:50: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['height'].replace('0','500', inplace=True)
# /tmp/ipykernel_582624/1127777538.py:51: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['height'].replace('1','1000', inplace=True)
# /tmp/ipykernel_582624/1127777538.py:52: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['height'].replace('2','1500', inplace=True)
# /tmp/ipykernel_582624/1127777538.py:53: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['height'].replace('3','2000', inplace=True)
# /tmp/ipykernel_582624/1127777538.py:54: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['height'].replace('4','2500', inplace=True)
# /tmp/ipykernel_582624/1127777538.py:55: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['height'].replace('5','3000', inplace=True)
# /tmp/ipykernel_582624/1127777538.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sel1.loc[:,'timeslice'] = '1971-2000'
# /tmp/ipykernel_582624/1127777538.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sel1.rename(columns = {var+'_1972-2001':var}, inplace = True)
# /tmp/ipykernel_582624/1127777538.py:71: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sela['experiment'] = sela['exp'].str.cat(sela['timeslice'],sep="-")
# /tmp/ipykernel_582624/1127777538.py:75: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sel2['timeslice']='2021-2050'
# /tmp/ipykernel_582624/1127777538.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sel2.rename(columns = {var+'_2022-2051':var}, inplace = True)
# /tmp/ipykernel_582624/1127777538.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sel3['timeslice']='2069-2098'
# /tmp/ipykernel_582624/1127777538.py:80: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sel3.rename(columns = {var+'_2070-2099':var}, inplace = True)
# /tmp/ipykernel_582624/502929277.py:12: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   ax=sns.stripplot(x=var, y='height', data=sel1r, dodge=True, alpha=0.9, jitter=0.2,
# Plot will be :  /home/g/g300047/SCRIPTS/github/snow-research/test-plots/BOXPLOTS/single_timeslice_region/Boxplot_snw_AL_2021-2050.png
# November-April 2021-2050 Europe
# /tmp/ipykernel_582624/502929277.py:12: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   ax=sns.stripplot(x=var, y='height', data=sel1r, dodge=True, alpha=0.9, jitter=0.2,
# Plot will be :  /home/g/g300047/SCRIPTS/github/snow-research/test-plots/BOXPLOTS/single_timeslice_region/Boxplot_snw_EU_2021-2050.png
# November-April 2021-2050 Eastern Europe
# Plot will be :  /home/g/g300047/SCRIPTS/github/snow-research/test-plots/BOXPLOTS/single_timeslice_region/Boxplot_snw_EA_2021-2050.png
# /tmp/ipykernel_582624/502929277.py:12: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   ax=sns.stripplot(x=var, y='height', data=sel1r, dodge=True, alpha=0.9, jitter=0.2,
# November-April 2021-2050 Iberian Peninsula
# /tmp/ipykernel_582624/502929277.py:12: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   ax=sns.stripplot(x=var, y='height', data=sel1r, dodge=True, alpha=0.9, jitter=0.2,
# Plot will be :  /home/g/g300047/SCRIPTS/github/snow-research/test-plots/BOXPLOTS/single_timeslice_region/Boxplot_snw_IP_2021-2050.png
# November-April 2021-2050 Scandinavia
# /tmp/ipykernel_582624/502929277.py:12: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   ax=sns.stripplot(x=var, y='height', data=sel1r, dodge=True, alpha=0.9, jitter=0.2,
# Plot will be :  /home/g/g300047/SCRIPTS/github/snow-research/test-plots/BOXPLOTS/single_timeslice_region/Boxplot_snw_SC_2021-2050.png
# November-April 2069-2098 Alps
# /tmp/ipykernel_582624/502929277.py:12: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   ax=sns.stripplot(x=var, y='height', data=sel1r, dodge=True, alpha=0.9, jitter=0.2,
# Plot will be :  /home/g/g300047/SCRIPTS/github/snow-research/test-plots/BOXPLOTS/single_timeslice_region/Boxplot_snw_AL_2069-2098.png
# November-April 2069-2098 Europe
# /tmp/ipykernel_582624/502929277.py:12: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   ax=sns.stripplot(x=var, y='height', data=sel1r, dodge=True, alpha=0.9, jitter=0.2,
# Plot will be :  /home/g/g300047/SCRIPTS/github/snow-research/test-plots/BOXPLOTS/single_timeslice_region/Boxplot_snw_EU_2069-2098.png
# November-April 2069-2098 Eastern Europe
# Plot will be :  /home/g/g300047/SCRIPTS/github/snow-research/test-plots/BOXPLOTS/single_timeslice_region/Boxplot_snw_EA_2069-2098.png
# /tmp/ipykernel_582624/502929277.py:12: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   ax=sns.stripplot(x=var, y='height', data=sel1r, dodge=True, alpha=0.9, jitter=0.2,
# November-April 2069-2098 Iberian Peninsula
# /tmp/ipykernel_582624/502929277.py:12: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   ax=sns.stripplot(x=var, y='height', data=sel1r, dodge=True, alpha=0.9, jitter=0.2,
# Plot will be :  /home/g/g300047/SCRIPTS/github/snow-research/test-plots/BOXPLOTS/single_timeslice_region/Boxplot_snw_IP_2069-2098.png
# November-April 2069-2098 Scandinavia
# /tmp/ipykernel_582624/502929277.py:12: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   ax=sns.stripplot(x=var, y='height', data=sel1r, dodge=True, alpha=0.9, jitter=0.2,
# Plot will be :  /home/g/g300047/SCRIPTS/github/snow-research/test-plots/BOXPLOTS/single_timeslice_region/Boxplot_snw_SC_2069-2098.png
